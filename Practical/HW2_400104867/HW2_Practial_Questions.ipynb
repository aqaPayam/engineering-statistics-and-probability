# %% [markdown]
# <div style="direction:rtl;line-height:300%;">
# 	<font face="XB Zar" size=5>
# 		<div align=center>
# 			<font face="IranNastaliq" size=30>
# 				<p></p>
# 				<p></p>
# به نام خدا
# 				<p></p>
# 			</font>
# 			<font color=#FF7500>
# دانشگاه صنعتی شریف - دانشکده مهندسی کامپیوتر
#             </font>
# 			<p></p>
# 			<font color=blue>
# آمار و احتمال مهندسی
#             </font>
# 			<br />
# 			<br />
# پاییز 1401
# 		</div>
# 		<hr/>
# 		<div align=center>
# 		    <font color=red size=6>
# 			    <br />
# تمرین عملی بخش دوم
#             	<br/>
# 			</font>
# طراحان: محمدجواد ماهرالنقش، محمد‌مهدی ابوترابی
# 			<br/><br/>
# موعد تحویل: 14 آبان
#                 <br/>
#                 همفکری در تمامی تمرین‌های درس توصیه می‌شود. در عین حال از شما خواسته می‌شود تا تمام پیاده‌سازی را به تنهایی و بدون مشاهده کد دیگران انجام دهید.
#                 <br/><br/>
#                 <font color=red>
#                 لطفا در فایل ارسالی تمام بلوک‌های کد اجرا شده و شامل نمودار‌ها و خروجی‌های لازم باشند.
#      </font>
#                 <br/>
#         </style>
# 	</font>
# </div>

# %% [markdown]
# <div style="direction:rtl">
#  نام و نام خانوادگی:
# </div>

# %% [markdown]
# <div style="direction:rtl">
#     شماره دانشجویی:
# </div>

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:250%;">
# 	<font face="XB Zar" size=5>
# 		<font color=#FF7500 size=6>
#              سوال اول
#         </font>
#         <hr/>
#         <div dir = "rtl" style="direction:rtl;line-height:200%;">
# 	<font face="XB Zar" size=5>
#     دیتافریم airquality یکی از دیتا فریم‌های biult-in است که اطلاعاتی در مورد وضعیت آب‌و‌هوای نیویورک در یک بازه‌ی زمانی می‌دهد.
#             </font>
# </div>
#     </font>
# </div>

# %%
library(ggplot2)
options(warn=-1)
head(airquality)
# Out:
#   Ozone Solar.R Wind Temp Month Day
# 1 41    190      7.4 67   5     1
# 2 36    118      8.0 72   5     2
# 3 12    149     12.6 74   5     3
# 4 18    313     11.5 62   5     4
# 5 NA     NA     14.3 56   5     5
# 6 28     NA     14.9 66   5     6

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:250%;">
# 	<font face="XB Zar" size=5>
#         الف)
# به کمک boxplot‌ها یک نمودار مناسب ارائه دهید که وضعیت دما (temp) را بر حسب ماه‌های مختلف نشان دهد.
#      </font>
# </div>

# %%
boxplot(airquality$Temp ~ airquality$Month ,xlab="Month",ylab="Temp", col="khaki")
# Out:
# plot without title

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:250%;">
# 	<font face="XB Zar" size=5>
# ب) بخش الف را برای میانگین باد و میانگین غلظت اوزون و میانگین تابش خورشید بر حسب ماه‌های مختلف تکرار کنید و نتایج خود را از این 4 نمودار شرح دهید.
#      </font>
# </div>

# %%
boxplot(airquality$Wind ~ airquality$Month ,xlab="Month",ylab="Wind", col="khaki")
boxplot(airquality$Ozone ~ airquality$Month ,xlab="Month",ylab="Ozone", col="khaki")
boxplot(airquality$Solar.R ~ airquality$Month ,xlab="Month",ylab="Solar.R", col="khaki")
# Out:
# plot without title
# plot without title
# plot without title

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:250%;">
# 	<font face="XB Zar" size=5>
#         بالا رفتن دما باعث کمتر شدن باد میشود و مقدار اوزون را بیشتر میکند که به دنبال آن تابش خورشید نیز بالا میرود
#      </font>
# </div>

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:250%;">
# 	<font face="XB Zar" size=5>
# ج) به کمک boxplot‌ها رنج اعداد مختلف در پارامتر‌های متفاوت را در این دیتاست را بررسی کنید.
#      </font>
# </div>

# %%
boxplot(airquality,col="khaki")
# Out:
# plot without title

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:250%;">
# 	<font face="XB Zar" size=5>
# د) به کمک نمودار scatter نمودار میانگین غلظت اوزون بر حسب دما را رسم کنید و آن را تحلیل کنید.
#      </font>
# </div>

# %%
ggplot(airquality,aes(x=Temp,y=Ozone))+geom_point(color="red",size=2)+geom_smooth(method = 'loess' , formula = 'y ~ x')
# Out:
# plot without title

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:250%;">
# 	<font face="XB Zar" size=5>
#     با افزایش دما میزان میانگین اوزون نیز بالا میرود
#     </font>
# </div>

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:250%;">
# 	<font face="XB Zar" size=5>
# ه) نمودار نقطه‌ای (scatter) را براساس ویژگی‌های جذر میانگین غلظت اوزون و ماه و باد رسم کنید. سعی کنید نمودار رسم شده اطلاعات را به خوبی نشان دهد. نتایج خود را بیان کنید. (به وابستگی میان متغیر‌ها توجه کنید.)
#      </font>
# </div>

# %%
ggplot(airquality,aes(x=Wind,y=sqrt(Ozone))) +geom_point(aes(color=factor(Month)),size=2.5)
# Out:
# plot without title

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:250%;">
# 	<font face="XB Zar" size=5>
#        نمودار نشان میدهد که مقدار میانگین اوزون با کم شدن باد بیشترمیشود و همچنین در دما های گرم تر بیشتر میشود
#     </font>
# </div>

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:250%;">
# 	<font face="XB Zar" size=5>
# و) نمودار هیستوگرام برای باد و  تابش خورشید رسم کنید، این دو نمودار را با هم و با نمودار توزیع نرمال مقایسه کنید و نتیجه‌ی خود را آن بیان کنید.
#      </font>
# </div>

# %%
ggplot(airquality,aes(x=Wind)) + geom_histogram(bins = 50,col="black",fill="khaki") 
ggplot(airquality,aes(x=Solar.R)) + geom_histogram(bins = 50,col="black",fill="khaki")
# Out:
# plot without title
# plot without title

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:250%;">
# 	<font face="XB Zar" size=5>
#         همانطور که میبینید نمودار اول بسیار به توزیع نرمالی با میانگین 10 شبیه تر است و نمودار دوم بیشتر ترکیبی از توزیع یونیفرم و توزیع نرمال است
#      </font>
# </div>

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:250%;">
# 	<font face="XB Zar" size=5>
# 		<font color=#FF7500 size=6>
#              سوال دوم
#         </font>
#         <hr/>
#         <div dir = "rtl" style="direction:rtl;line-height:200%;">
# 	<font face="XB Zar" size=5>
#         در یک فرایند پواسون زمان بین دو اتفاق از یک توزیع نمایی پیروی می‌کند. اگر بخواهیم زمان اتفاق n‌ام را پیش‌بینی کنیم از توزیع گاما استفاده می‌کنیم.
#         $$T_n=\sum_{i=1}^n{X_i},\  X_i  s\ are\ i.i.d\ and\ X_i\sim Exp(\lambda)$$
#         $$T_n\sim Gamma(n, \lambda)$$
# حال فرض کنید فاصله بین ورود مشتریان به یک رستوران از توزیع نمایی پیروی می‌کند به طوری که در هر دقیقه پنج مشتری وارد می‌شوند.
#         <br>
#         الف)
#  2000  نمونه تصادفی برای زمان بین ورود مشتریان تولید کنید و نمودارهای هیستوگرام داده‌های تولیدشده و چگالی توزیع آن را در یک نمودار رسم کنید. نمودار هیستوگرام شما باید چگالی احتمال را برای هر نمونه را نشان دهد.
#             </font>
# </div>
#     </font>
# </div>

# %%
data <-rexp(2000,5)
hist(data,freq=FALSE,breaks=30,col="green")
lines(density(data),lwd=2.5)
# Out:
# Plot with title "Histogram of data"

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:250%;">
# 	<font face="XB Zar" size=5>
#         ب)
#         بی‌حافظگی توزیع نمایی را با داده‌های تولید شده در قسمت قبل را با استفاده از داده‌های تولید شده در قسمت قبل و رسم نمودار به همان شکل نشان دهید.
#      </font>
# </div>

# %%
newData <- data[data > 0.25] - 0.25
hist(newData,freq=FALSE,breaks=30,col="green")
lines(density(newData),lwd=2.5)
# Out:
# Plot with title "Histogram of newData"

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:250%;">
# 	<font face="XB Zar" size=5>
#         ج)
#        با تولید n=10 متغیرتصادفی نمایی، ویژگی گفته شده در صورت سوال را بررسی کنید. برای این‌کار می‌توانید برای شبیه‌سازی هر متغیرتصادفی مانند قسمت الف عمل کنید.
#      </font>
# </div>

# %%
data <- rexp(2000, 5)
for(i in 1:9)
    data <- data + rexp(2000, 5)
gamma_dist <- rgamma(2000,10,rate= 5)
den_exp<-density(data)
den_gamma <- density(gamma_dist)
plot(den_exp,lwd=5,col="green")
lines(den_gamma,lwd=5,col="red")
# Out:
# Plot with title "density.default(x = data)"

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:250%;">
# 	<font face="XB Zar" size=5>
# 		<font color=#FF7500 size=6>
#              سوال سوم
#         </font>
#         <hr/>
#         <div dir = "rtl" style="direction:rtl;line-height:200%;">
# 	<font face="XB Zar" size=5>
#     دیتاست مربوط به درآمد در پیوست موجود است. <br>
#     الف) به وسیلۀ دستور read.csv اطلاعات دیتاست را بخوانید. (دیتاست adult.csv)
#             </font>
# </div>
#     </font>
# </div>

# %%
adult <- read.csv("adult.csv")
adult
# Out:
#       age workclass        fnlwgt education    educational.num
# 1     25  Private          226802 11th          7
# 2     38  Private           89814 HS-grad       9
# 3     28  Local-gov        336951 Assoc-acdm   12
# 4     44  Private          160323 Some-college 10
# 5     18  ?                103497 Some-college 10
# 6     34  Private          198693 10th          6
# 7     29  ?                227026 HS-grad       9
# 8     63  Self-emp-not-inc 104626 Prof-school  15
# 9     24  Private          369667 Some-college 10
# 10    55  Private          104996 7th-8th       4
# 11    65  Private          184454 HS-grad       9
# 12    36  Federal-gov      212465 Bachelors    13
# 13    26  Private           82091 HS-grad       9
# 14    58  ?                299831 HS-grad       9
# 15    48  Private          279724 HS-grad       9
# 16    43  Private          346189 Masters      14
# 17    20  State-gov        444554 Some-college 10
# 18    43  Private          128354 HS-grad       9
# 19    37  Private           60548 HS-grad       9
# 20    40  Private           85019 Doctorate    16
# 21    34  Private          107914 Bachelors    13
# 22    34  Private          238588 Some-college 10
# 23    72  ?                132015 7th-8th       4
# 24    25  Private          220931 Bachelors    13
# 25    25  Private          205947 Bachelors    13
# 26    45  Self-emp-not-inc 432824 HS-grad       9
# 27    22  Private          236427 HS-grad       9
# 28    23  Private          134446 HS-grad       9
# 29    54  Private           99516 HS-grad       9
# 30    32  Self-emp-not-inc 109282 Some-college 10
# ⋮     ⋮   ⋮                ⋮      ⋮            ⋮
# 48813 30  ?                 33811 Bachelors    13
# 48814 34  Private          204461 Doctorate    16
# 48815 54  Private          337992 Bachelors    13
# 48816 37  Private          179137 Some-college 10
# 48817 22  Private          325033 12th          8
# 48818 34  Private          160216 Bachelors    13
# 48819 30  Private          345898 HS-grad       9
# 48820 38  Private          139180 Bachelors    13
# 48821 71  ?                287372 Doctorate    16
# 48822 45  State-gov        252208 HS-grad       9
# 48823 41  ?                202822 HS-grad       9
# 48824 72  ?                129912 HS-grad       9
# 48825 45  Local-gov        119199 Assoc-acdm   12
# 48826 31  Private          199655 Masters      14
# 48827 39  Local-gov        111499 Assoc-acdm   12
# 48828 37  Private          198216 Assoc-acdm   12
# 48829 43  Private          260761 HS-grad       9
# 48830 65  Self-emp-not-inc  99359 Prof-school  15
# 48831 43  State-gov        255835 Some-college 10
# 48832 43  Self-emp-not-inc  27242 Some-college 10
# 48833 32  Private           34066 10th          6
# 48834 43  Private           84661 Assoc-voc    11
# 48835 32  Private          116138 Masters      14
# 48836 53  Private          321865 Masters      14
# 48837 22  Private          310152 Some-college 10
# 48838 27  Private          257302 Assoc-acdm   12
# 48839 40  Private          154374 HS-grad       9
# 48840 58  Private          151910 HS-grad       9
# 48841 22  Private          201490 HS-grad       9
# 48842 52  Self-emp-inc     287927 HS-grad       9
#       marital.status     occupation        relationship   race
# 1     Never-married      Machine-op-inspct Own-child      Black
# 2     Married-civ-spouse Farming-fishing   Husband        White
# 3     Married-civ-spouse Protective-serv   Husband        White
# 4     Married-civ-spouse Machine-op-inspct Husband        Black
# 5     Never-married      ?                 Own-child      White
# 6     Never-married      Other-service     Not-in-family  White
# 7     Never-married      ?                 Unmarried      Black
# 8     Married-civ-spouse Prof-specialty    Husband        White
# 9     Never-married      Other-service     Unmarried      White
# 10    Married-civ-spouse Craft-repair      Husband        White
# 11    Married-civ-spouse Machine-op-inspct Husband        White
# 12    Married-civ-spouse Adm-clerical      Husband        White
# 13    Never-married      Adm-clerical      Not-in-family  White
# 14    Married-civ-spouse ?                 Husband        White
# 15    Married-civ-spouse Machine-op-inspct Husband        White
# 16    Married-civ-spouse Exec-managerial   Husband        White
# 17    Never-married      Other-service     Own-child      White
# 18    Married-civ-spouse Adm-clerical      Wife           White
# 19    Widowed            Machine-op-inspct Unmarried      White
# 20    Married-civ-spouse Prof-specialty    Husband        Asian-Pac-Islander
# 21    Married-civ-spouse Tech-support      Husband        White
# 22    Never-married      Other-service     Own-child      Black
# 23    Divorced           ?                 Not-in-family  White
# 24    Never-married      Prof-specialty    Not-in-family  White
# 25    Married-civ-spouse Prof-specialty    Husband        White
# 26    Married-civ-spouse Craft-repair      Husband        White
# 27    Never-married      Adm-clerical      Own-child      White
# 28    Separated          Machine-op-inspct Unmarried      Black
# 29    Married-civ-spouse Craft-repair      Husband        White
# 30    Never-married      Prof-specialty    Not-in-family  White
# ⋮     ⋮                  ⋮                 ⋮              ⋮
# 48813 Never-married      ?                 Not-in-family  Asian-Pac-Islander
# 48814 Married-civ-spouse Prof-specialty    Husband        White
# 48815 Married-civ-spouse Exec-managerial   Husband        Asian-Pac-Islander
# 48816 Divorced           Adm-clerical      Unmarried      White
# 48817 Never-married      Protective-serv   Own-child      Black
# 48818 Never-married      Exec-managerial   Not-in-family  White
# 48819 Never-married      Craft-repair      Not-in-family  Black
# 48820 Divorced           Prof-specialty    Unmarried      Black
# 48821 Married-civ-spouse ?                 Husband        White
# 48822 Separated          Adm-clerical      Own-child      White
# 48823 Separated          ?                 Not-in-family  Black
# 48824 Married-civ-spouse ?                 Husband        White
# 48825 Divorced           Prof-specialty    Unmarried      White
# 48826 Divorced           Other-service     Not-in-family  Other
# 48827 Married-civ-spouse Adm-clerical      Wife           White
# 48828 Divorced           Tech-support      Not-in-family  White
# 48829 Married-civ-spouse Machine-op-inspct Husband        White
# 48830 Never-married      Prof-specialty    Not-in-family  White
# 48831 Divorced           Adm-clerical      Other-relative White
# 48832 Married-civ-spouse Craft-repair      Husband        White
# 48833 Married-civ-spouse Handlers-cleaners Husband        Amer-Indian-Eskimo
# 48834 Married-civ-spouse Sales             Husband        White
# 48835 Never-married      Tech-support      Not-in-family  Asian-Pac-Islander
# 48836 Married-civ-spouse Exec-managerial   Husband        White
# 48837 Never-married      Protective-serv   Not-in-family  White
# 48838 Married-civ-spouse Tech-support      Wife           White
# 48839 Married-civ-spouse Machine-op-inspct Husband        White
# 48840 Widowed            Adm-clerical      Unmarried      White
# 48841 Never-married      Adm-clerical      Own-child      White
# 48842 Married-civ-spouse Exec-managerial   Wife           White
#       gender capital.gain capital.loss hours.per.week native.country income
# 1     Male      0         0            40             United-States  <=50K
# 2     Male      0         0            50             United-States  <=50K
# 3     Male      0         0            40             United-States  >50K
# 4     Male   7688         0            40             United-States  >50K
# 5     Female    0         0            30             United-States  <=50K
# 6     Male      0         0            30             United-States  <=50K
# 7     Male      0         0            40             United-States  <=50K
# 8     Male   3103         0            32             United-States  >50K
# 9     Female    0         0            40             United-States  <=50K
# 10    Male      0         0            10             United-States  <=50K
# 11    Male   6418         0            40             United-States  >50K
# 12    Male      0         0            40             United-States  <=50K
# 13    Female    0         0            39             United-States  <=50K
# 14    Male      0         0            35             United-States  <=50K
# 15    Male   3103         0            48             United-States  >50K
# 16    Male      0         0            50             United-States  >50K
# 17    Male      0         0            25             United-States  <=50K
# 18    Female    0         0            30             United-States  <=50K
# 19    Female    0         0            20             United-States  <=50K
# 20    Male      0         0            45             ?              >50K
# 21    Male      0         0            47             United-States  >50K
# 22    Female    0         0            35             United-States  <=50K
# 23    Female    0         0             6             United-States  <=50K
# 24    Male      0         0            43             Peru           <=50K
# 25    Male      0         0            40             United-States  <=50K
# 26    Male   7298         0            90             United-States  >50K
# 27    Male      0         0            20             United-States  <=50K
# 28    Male      0         0            54             United-States  <=50K
# 29    Male      0         0            35             United-States  <=50K
# 30    Male      0         0            60             United-States  <=50K
# ⋮     ⋮      ⋮            ⋮            ⋮              ⋮              ⋮
# 48813 Female     0        0            99             United-States  <=50K
# 48814 Male       0        0            60             United-States  >50K
# 48815 Male       0        0            50             Japan          >50K
# 48816 Female     0        0            39             United-States  <=50K
# 48817 Male       0        0            35             United-States  <=50K
# 48818 Female     0        0            55             United-States  >50K
# 48819 Male       0        0            46             United-States  <=50K
# 48820 Female 15020        0            45             United-States  >50K
# 48821 Male       0        0            10             United-States  >50K
# 48822 Female     0        0            40             United-States  <=50K
# 48823 Female     0        0            32             United-States  <=50K
# 48824 Male       0        0            25             United-States  <=50K
# 48825 Female     0        0            48             United-States  <=50K
# 48826 Female     0        0            30             United-States  <=50K
# 48827 Female     0        0            20             United-States  >50K
# 48828 Female     0        0            40             United-States  <=50K
# 48829 Male       0        0            40             Mexico         <=50K
# 48830 Male    1086        0            60             United-States  <=50K
# 48831 Female     0        0            40             United-States  <=50K
# 48832 Male       0        0            50             United-States  <=50K
# 48833 Male       0        0            40             United-States  <=50K
# 48834 Male       0        0            45             United-States  <=50K
# 48835 Male       0        0            11             Taiwan         <=50K
# 48836 Male       0        0            40             United-States  >50K
# 48837 Male       0        0            40             United-States  <=50K
# 48838 Female     0        0            38             United-States  <=50K
# 48839 Male       0        0            40             United-States  >50K
# 48840 Female     0        0            40             United-States  <=50K
# 48841 Male       0        0            20             United-States  <=50K
# 48842 Female 15024        0            40             United-States  >50K

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:250%;">
# 	<font face="XB Zar" size=5>
#         نمودار مربوط به درآمد را برحسب سن/جنسیت به کمک نمودارهای زیر بکشید.
#      </font>
# </div>

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:250%;">
# 	<font face="XB Zar" size=5>
#          ب) نمودار Bar Plot (درآمد برحسب جنسیت و سن)
#      </font>
# </div>

# %%
library(ggplot2)
ggplot(adult, aes(x=income, y=age, fill = gender)) + geom_bar(stat="identity", position=position_dodge())
# Out:
# plot without title

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:250%;">
# 	<font face="XB Zar" size=5>
#         ج) نمودار Scatter Plot
#      </font>
# </div>

# %%
 ggplot(adult, aes(x=income, y=age )) +  geom_point(aes(color = gender))
# Out:
# plot without title

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:250%;">
# 	<font face="XB Zar" size=5>
#         د) نمودار Histogram (مربوط به سن که اطلاعات زن و مرد در یک نمودار به طور تلفیقی باشد)
#      </font>
# </div>

# %%
 ggplot(adult, aes(x=age, fill = income,color=gender)) + 
    geom_histogram( binwidth=2)
# Out:
# plot without title

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:250%;">
# 	<font face="XB Zar" size=5>
#        ه) نمودار Density Plot (مربوط به سن که اطلاعات زن و مرد در یک نمودار به طور تلفیقی باشد)
#      </font>
# </div>

# %%
ggplot(adult, aes(x=age,fill=income, color=gender)) +
  geom_density(linewidth = 2)
# Out:
# plot without title

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:250%;">
# 	<font face="XB Zar" size=5>
#          و) نمودار Trend Plot
#      </font>
# </div>

# %%
ggplot(adult, aes(x=age, y=income, color = gender)) + 
    geom_point(stat="identity") + 
    geom_smooth(aes(group = gender, fill = gender), method = "gam", formula = y ~ s(x, bs = 'cs'))
# Out:
# plot without title

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:250%;">
# 	<font face="XB Zar" size=5>
# 		<font color=#FF7500 size=6>
#              سوال چهارم
#         </font>
#         <hr/>
#         <div dir = "rtl" style="direction:rtl;line-height:200%;">
# 	<font face="XB Zar" size=5>
#     نمودار توزیع های احتمالی زیر را با توجه به به پارامترهای داده شده رسم کنید. <br> الف) نمودار توزیع پوآسون (در بازۀ 0 تا 50 با پارامتر 10)
#             </font>
# </div>
#     </font>
# </div>

# %%
plot(dpois(seq(0,50),10),type="o")
# Out:
# plot without title

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:250%;">
# 	<font face="XB Zar" size=5>
# ب) نمودار توزیع برنولی (در بازۀ 0 تا 5 با پارامتر 0.6)
#      </font>
# </div>

# %%
plot(dbinom(seq(0,5),1,0.6),type="o")
# Out:
# plot without title

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:250%;">
# 	<font face="XB Zar" size=5>
#     ج) نمودار توزیع دو جمله ای (در بازۀ 0 تا 20 با پارامتر 0.2)
#     </font>
# </div>

# %%
plot(dbinom(seq(0,20) , 20,0.2),type="o")
# Out:
# plot without title

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:250%;">
# 	<font face="XB Zar" size=5>
#     د) نمودار توزیع هندسی (در بازۀ 0 تا 10 با پارامترهای p = 0.2 و n = 3)
#     </font>
# </div>

# %%
plot(dgeom(seq(0,10),0.2),type="o")
# Out:
# plot without title

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:250%;">
# 	<font face="XB Zar" size=5>
#     ه) نمودار توزیع نرمال (در بازۀ 4- تا 4)
#      </font>
# </div>

# %%
plot(seq(-4,4,0.01),dnorm(seq(-4,4,0.01),0,1))
# Out:
# plot without title

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:250%;">
# 	<font face="XB Zar" size=5>
#     و) نمودار توزیع نمایی (در بازۀ 0 تا 10 با پارامتر 1.5)
#      </font>
# </div>

# %%
plot(seq(0,10,0.01),dexp(seq(0,10,0.01),1.5))
# Out:
# plot without title

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:250%;">
# 	<font face="XB Zar" size=5>
#      ز) نمودار توزیع یکنواخت (در بازۀ 4- تا 4)
#      </font>
# </div>

# %%
plot(seq(-4,4,0.01),dunif(seq(-4,4,0.01),-4,4))
# Out:
# plot without title
